# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import sys

sys.path.append("../src")

# %%
from initialization import ENVIRONMENT, DB_URL
(ENVIRONMENT, DB_URL)
# Out:
# ('development', 'sqlite:///database.db')
