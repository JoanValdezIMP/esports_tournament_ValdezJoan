# %%
import os
from dotenv import load_dotenv
import sys

sys.path.append("../src")
load_dotenv()
# Out:
# True

# %%
from domain import (
    Base,
    engine
)


# ENVIRONMENT, DB_URL (ENVIRONMENT, DB_URL)

# %%
Base.metadata.create_all(engine)

print(Base.metadata.tables.keys())
# Out:
# dict_keys([])
