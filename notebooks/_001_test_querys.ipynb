# %%
import os
from dotenv import load_dotenv
import sys

sys.path.append("../src")
load_dotenv()
# Out:
# True

# %%
import os
import sys
from datetime import date, datetime


from domain.config import DB_URL
from repositories import UnitOfWorkFactory
from models import (
    Region, Player, Team, VideoGameType, 
    TournamentMode, TournamentStatus, Tournament, Match
)
from repositories import (
    PlayerRepository, TeamRepository, TournamentRepository, RegionRepository
)

print(f"Conectando a: {DB_URL}")
# Out:
# Conectando a: sqlite:///./test_db.sqlite
