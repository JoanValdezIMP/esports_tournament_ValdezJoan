# %%
from domain import Base, engine

Base.metadata.create_all(engine)

# %%
import sys

sys.path.append('../src')
from domain import Session, Player, PlayerRepository
# engine.url

# %%
from domain import Session, Player

session = Session()

player = session.get(Player, 1)

if player:
    print(player.id, player.nickname)
else:
    print("No existe")
# Out:
# No existe
