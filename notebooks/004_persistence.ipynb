# %%
import sys

sys.path.append('../src')

# %%
from domain import (
    Base,
    Session, 
    engine,
    VideoGameType,
    VideoGameTypeRepository,
    VideoGameType,
    Region
)

engine.url
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from domain import (
#       2     Base,
#       3     Session,
#       4     engine,
#       5     VideoGameType,
#       6     VideoGameTypeRepository,
#       7     VideoGameType,
#       8     Region
#       9 )
#      11 engine.url
#
# File c:\Users\10066920\Desktop\eTournament\esports_tournament_ValdezJoan\notebooks\../src\domain\__init__.py:20
#       5 # IMPORTANTE: Importamos todos los modelos aquí para que Base.metadata los registre
#       6 from .models import (
#       7     Region,
#       8     VideoGameType,
#    (...)     17     Match
#      18 )
# ---> 20 from .repositories import (
#      21     VideoGameTypeRepository,
#      22     RegionRepository
#      23 )
#
# File c:\Users\10066920\Desktop\eTournament\esports_tournament_ValdezJoan\notebooks\../src\domain\repositories.py:65
#      60         if len(r.country_code) > 10:
#      61             raise ValueError("Country code demasiado largo")
# ---> 65 class PlayerRepository(Repository[Player]):
#      67     def _validate(self, p: Player):
#      69         if not p.nickname or p.nickname.strip() == "":
#
# NameError: name 'Player' is not defined

# %%
Base.metadata.create_all(engine)

print(Base.metadata.tables.keys())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 Base.metadata.create_all(engine)
#       3 print(Base.metadata.tables.keys())
#
# NameError: name 'Base' is not defined

# %%
session = Session()


tetris = VideoGameType()

tetris.name = "Tetris"
tetris.description = "A tile-matching puzzle video game."


videogame_repository = VideoGameTypeRepository(session)
videogame_repository.save(tetris)

session.commit()

# En lugar de pasar el objeto 'tetris', pasa su ID


result = videogame_repository.get(tetris.id_video_game_type)

print(f"id: {result.id_video_game_type}, name: {result.name}, description: {result.description}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 11
#       7 tetris.description = "A tile-matching puzzle video game."
#      10 videogame_repository = VideoGameTypeRepository(session)
# ---> 11 videogame_repository.save(tetris)
#      13 session.commit()
#      15 # En lugar de pasar el objeto 'tetris', pasa su ID
#
# File c:\Users\10066920\Desktop\eTournament\esports_tournament_ValdezJoan\notebooks\../src\domain\repositories.py:27, in Repository.save(self, t)
#      26 def save(self, t: T):
# ---> 27     if t.id == None:
#      28         self.session.add(t)
#      29     else:
#      30         # self.update(t)
#
# AttributeError: 'VideoGameType' object has no attribute 'id'
